# %% [markdown]
# # Fine-Tuning DeepSeek with Your Own Data
# This notebook will help you fine-tune the DeepSeek-Coder model using your resume data. We use **LoRA** (Low-Rank Adaptation) to make training fast and memory-efficient.
